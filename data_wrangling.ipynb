# %% [markdown]
# ###### imports

# %%
import pandas as pd
import re
import pulp

# %% [markdown]
# ##### data wrangling

# %%
data = pd.read_csv('./Data/kaggle_data.csv') #read in the kaggle nutrition data.

data = data.drop(columns=["Unnamed: 0"]) # get rid of extra index
data = data.astype(str) # convert all columns to strings

# %%
s = data.iloc[1,1]
print(s)
alpha = re.compile(r"[a-z]+")
m = alpha.search(s)
m.group()
# Out:
# 100 g
# 'g'

# %%
data.columns
# Out:
# Index(['name', 'serving_size', 'calories', 'total_fat', 'saturated_fat',
#        'cholesterol', 'sodium', 'choline', 'folate', 'folic_acid', 'niacin',
#        'pantothenic_acid', 'riboflavin', 'thiamin', 'vitamin_a',
#        'vitamin_a_rae', 'carotene_alpha', 'carotene_beta',
#        'cryptoxanthin_beta', 'lutein_zeaxanthin', 'lucopene', 'vitamin_b12',
#        'vitamin_b6', 'vitamin_c', 'vitamin_d', 'vitamin_e', 'tocopherol_alpha',
#        'vitamin_k', 'calcium', 'copper', 'irom', 'magnesium', 'manganese',
#        'phosphorous', 'potassium', 'selenium', 'zink', 'protein', 'alanine',
#        'arginine', 'aspartic_acid', 'cystine', 'glutamic_acid', 'glycine',
#        'histidine', 'hydroxyproline', 'isoleucine', 'leucine', 'lysine',
#        'methionine', 'phenylalanine', 'proline', 'serine', 'threonine',
#        'tryptophan', 'tyrosine', 'valine', 'carbohydrate', 'fiber', 'sugars',
#        'fructose', 'galactose', 'glucose', 'lactose', 'maltose', 'sucrose',
#        'fat', 'saturated_fatty_acids', 'monounsaturated_fatty_acids',
#        'polyunsaturated_fatty_acids', 'fatty_acids_total_trans', 'alcohol',
#        'ash', 'caffeine', 'theobromine', 'water'],
#       dtype='object')

# %%
# 'zink' should be 'zinc'
data = data.rename({'zink':'zinc'},
            axis=1)
data.zinc
# Out:
# 0       0.06 mg
# 1       4.53 mg
# 2       0.16 mg
# 3       3.63 mg
# 4       0.48 mg
#          ...
# 8784    3.67 mg
# 8785    4.30 mg
# 8786    2.39 mg
# 8787    3.42 mg
# 8788    3.42 mg
# Name: zinc, Length: 8789, dtype: object

# %%
data.columns[1]
# Out:
# 'serving_size'

# %%
# Generate a dictionary of units for the different nutrient types (serving_size, 
# calories, etc.)
units = {}
for r in range(1,len(data.columns)):  # for each of the nutrient labels
    alpha = re.compile(r"[mcgiu]+",re.I) # generate pattern object
    i = 0 # start with 1st nutrient value
    s = data.iat[i,r] # get nutrient value
    m = alpha.search(s) # check pattern object against nutrient value, 
                        # generating match object
    # try:
    #     print(m.group())
    # except:
    #     print("no match")
    try:
        units[data.columns[r]] = m.group()
    except:
        while not m:
            # loop through until we have a unit or decide there are no units
            i = i+1 # go to next value
            s = data.iat[i,r] # store value
            m = alpha.search(s) # search value against the pattern

            try: # store match if there is one
                units[data.columns[r]] = m.group() 
            except: 
                if i==data.shape[0]-1: # if no units found by end, None units
                    m = "None"
                    units[data.columns[r]] = m

# %%
units
# Out:
# {'serving_size': 'g',
#  'calories': 'None',
#  'total_fat': 'g',
#  'saturated_fat': 'g',
#  'cholesterol': 'mg',
#  'sodium': 'mg',
#  'choline': 'mg',
#  'folate': 'mcg',
#  'folic_acid': 'mcg',
#  'niacin': 'mg',
#  'pantothenic_acid': 'mg',
#  'riboflavin': 'mg',
#  'thiamin': 'mg',
#  'vitamin_a': 'IU',
#  'vitamin_a_rae': 'mcg',
#  'carotene_alpha': 'mcg',
#  'carotene_beta': 'mcg',
#  'cryptoxanthin_beta': 'mcg',
#  'lutein_zeaxanthin': 'mcg',
#  'lucopene': 'None',
#  'vitamin_b12': 'mcg',
#  'vitamin_b6': 'mg',
#  'vitamin_c': 'mg',
#  'vitamin_d': 'IU',
#  'vitamin_e': 'mg',
#  'tocopherol_alpha': 'mg',
#  'vitamin_k': 'mcg',
#  'calcium': 'mg',
#  'copper': 'mg',
#  'irom': 'mg',
#  'magnesium': 'mg',
#  'manganese': 'mg',
#  'phosphorous': 'mg',
#  'potassium': 'mg',
#  'selenium': 'mcg',
#  'zinc': 'mg',
#  'protein': 'g',
#  'alanine': 'g',
#  'arginine': 'g',
#  'aspartic_acid': 'g',
#  'cystine': 'g',
#  'glutamic_acid': 'g',
#  'glycine': 'g',
#  'histidine': 'g',
#  'hydroxyproline': 'g',
#  'isoleucine': 'g',
#  'leucine': 'g',
#  'lysine': 'g',
#  'methionine': 'g',
#  'phenylalanine': 'g',
#  'proline': 'g',
#  'serine': 'g',
#  'threonine': 'g',
#  'tryptophan': 'g',
#  'tyrosine': 'g',
#  'valine': 'g',
#  'carbohydrate': 'g',
#  'fiber': 'g',
#  'sugars': 'g',
#  'fructose': 'g',
#  'galactose': 'g',
#  'glucose': 'g',
#  'lactose': 'g',
#  'maltose': 'g',
#  'sucrose': 'g',
#  'fat': 'g',
#  'saturated_fatty_acids': 'g',
#  'monounsaturated_fatty_acids': 'g',
#  'polyunsaturated_fatty_acids': 'g',
#  'fatty_acids_total_trans': 'mg',
#  'alcohol': 'g',
#  'ash': 'g',
#  'caffeine': 'mg',
#  'theobromine': 'mg',
#  'water': 'g'}

# %%
data.head() # looking at the data again, I need to remove the units, and replace 
            # nan with 0
# Out:
#               name serving_size calories total_fat saturated_fat cholesterol  \
# 0       Cornstarch        100 g      381      0.1g           nan           0
# 1     Nuts, pecans        100 g      691       72g          6.2g           0
# 2    Eggplant, raw        100 g       25      0.2g           nan           0
# 3   Teff, uncooked        100 g      367      2.4g          0.4g           0
# 4  Sherbet, orange        100 g      144        2g          1.2g         1mg
#
#      sodium  choline     folate folic_acid  ...      fat  \
# 0   9.00 mg   0.4 mg   0.00 mcg   0.00 mcg  ...   0.05 g
# 1   0.00 mg  40.5 mg  22.00 mcg   0.00 mcg  ...  71.97 g
# 2   2.00 mg   6.9 mg  22.00 mcg   0.00 mcg  ...   0.18 g
# 3  12.00 mg  13.1 mg          0          0  ...   2.38 g
# 4  46.00 mg   7.7 mg   4.00 mcg   0.00 mcg  ...   2.00 g
#
#   saturated_fatty_acids monounsaturated_fatty_acids  \
# 0               0.009 g                     0.016 g
# 1               6.180 g                    40.801 g
# 2               0.034 g                     0.016 g
# 3               0.449 g                     0.589 g
# 4               1.160 g                     0.530 g
#
#   polyunsaturated_fatty_acids fatty_acids_total_trans alcohol     ash  \
# 0                     0.025 g                 0.00 mg   0.0 g  0.09 g
# 1                    21.614 g                 0.00 mg   0.0 g  1.49 g
# 2                     0.076 g                 0.00 mg   0.0 g  0.66 g
# 3                     1.071 g                       0       0  2.37 g
# 4                     0.080 g                 1.00 mg   0.0 g  0.40 g
#
#   caffeine theobromine    water
# 0  0.00 mg     0.00 mg   8.32 g
# 1  0.00 mg     0.00 mg   3.52 g
# 2  0.00 mg     0.00 mg  92.30 g
# 3        0           0   8.82 g
# 4  0.00 mg     0.00 mg  66.10 g
#
# [5 rows x 76 columns]

# %%
# Generate a dictionary of units for the different info types (serving_size, 
# calories, etc.)

units = {}
for r in range(1,len(data.columns)):  # for each of the nutrient labels
    pattern_units = re.compile(r"[mcgiu]+",re.I) # generate pattern object
    i = 0 # start with 1st nutrient value
    s = data.iat[i,r] # get nutrient value
    m = pattern_units.search(s) # check pattern object against nutrient value, 
                        # generating match object
    # try:
    #     print(m.group())
    # except:
    #     print("no match")
    try:
        units[data.columns[r]] = m.group()
    except:
        while not m:
            # loop through until we have a unit or decide there are no units
            i = i+1 # go to next value
            s = data.iat[i,r] # store value
            m = pattern_units.search(s) # search value against the pattern

            try: # store match if there is one
                units[data.columns[r]] = m.group() 
            except: 
                if i==data.shape[0]-1: # if no units found by end, None units
                    m = "None"
                    units[data.columns[r]] = m

# %% [markdown]
#  per [Joao Silva, stack overflow](https://stackoverflow.com/questions/1450897/remove-characters-except-digits-from-string-using-python), use re.sub to replace digits.  Need to tweak to keep the decimal

# %%
data.head()
# Out:
#               name serving_size calories total_fat saturated_fat cholesterol  \
# 0       Cornstarch        100 g      381      0.1g           nan           0
# 1     Nuts, pecans        100 g      691       72g          6.2g           0
# 2    Eggplant, raw        100 g       25      0.2g           nan           0
# 3   Teff, uncooked        100 g      367      2.4g          0.4g           0
# 4  Sherbet, orange        100 g      144        2g          1.2g         1mg
#
#      sodium  choline     folate folic_acid  ...      fat  \
# 0   9.00 mg   0.4 mg   0.00 mcg   0.00 mcg  ...   0.05 g
# 1   0.00 mg  40.5 mg  22.00 mcg   0.00 mcg  ...  71.97 g
# 2   2.00 mg   6.9 mg  22.00 mcg   0.00 mcg  ...   0.18 g
# 3  12.00 mg  13.1 mg          0          0  ...   2.38 g
# 4  46.00 mg   7.7 mg   4.00 mcg   0.00 mcg  ...   2.00 g
#
#   saturated_fatty_acids monounsaturated_fatty_acids  \
# 0               0.009 g                     0.016 g
# 1               6.180 g                    40.801 g
# 2               0.034 g                     0.016 g
# 3               0.449 g                     0.589 g
# 4               1.160 g                     0.530 g
#
#   polyunsaturated_fatty_acids fatty_acids_total_trans alcohol     ash  \
# 0                     0.025 g                 0.00 mg   0.0 g  0.09 g
# 1                    21.614 g                 0.00 mg   0.0 g  1.49 g
# 2                     0.076 g                 0.00 mg   0.0 g  0.66 g
# 3                     1.071 g                       0       0  2.37 g
# 4                     0.080 g                 1.00 mg   0.0 g  0.40 g
#
#   caffeine theobromine    water
# 0  0.00 mg     0.00 mg   8.32 g
# 1  0.00 mg     0.00 mg   3.52 g
# 2  0.00 mg     0.00 mg  92.30 g
# 3        0           0   8.82 g
# 4  0.00 mg     0.00 mg  66.10 g
#
# [5 rows x 76 columns]

# %%
data.shape[1]
# Out:
# 76

# %%
# remove all of the units, which have been stored and should be constant across 
# all of the food types for each nutrient

for c in range(1,data.shape[1]):
    for r in range(0,data.shape[0]):
        try:
            data.iat[r,c] = float(re.sub(r"[^0-9.]","",str(data.iat[r,c])))
        except (ValueError):
            pass

# %%
data.head()
# Out:
#               name serving_size calories total_fat saturated_fat cholesterol  \
# 0       Cornstarch        100.0    381.0       0.1           nan         0.0
# 1     Nuts, pecans        100.0    691.0      72.0           6.2         0.0
# 2    Eggplant, raw        100.0     25.0       0.2           nan         0.0
# 3   Teff, uncooked        100.0    367.0       2.4           0.4         0.0
# 4  Sherbet, orange        100.0    144.0       2.0           1.2         1.0
#
#   sodium choline folate folic_acid  ...    fat saturated_fatty_acids  \
# 0    9.0     0.4    0.0        0.0  ...   0.05                 0.009
# 1    0.0    40.5   22.0        0.0  ...  71.97                  6.18
# 2    2.0     6.9   22.0        0.0  ...   0.18                 0.034
# 3   12.0    13.1    0.0        0.0  ...   2.38                 0.449
# 4   46.0     7.7    4.0        0.0  ...    2.0                  1.16
#
#   monounsaturated_fatty_acids polyunsaturated_fatty_acids  \
# 0                       0.016                       0.025
# 1                      40.801                      21.614
# 2                       0.016                       0.076
# 3                       0.589                       1.071
# 4                        0.53                        0.08
#
#   fatty_acids_total_trans alcohol   ash caffeine theobromine water
# 0                     0.0     0.0  0.09      0.0         0.0  8.32
# 1                     0.0     0.0  1.49      0.0         0.0  3.52
# 2                     0.0     0.0  0.66      0.0         0.0  92.3
# 3                     0.0     0.0  2.37      0.0         0.0  8.82
# 4                     1.0     0.0   0.4      0.0         0.0  66.1
#
# [5 rows x 76 columns]

# %%
# find the food, nutrient coordinates of the 'nan' values for inspection and 
# confirmation that they can be safely converted to float('0').

nan_coord = []
for c in range(1,data.shape[1]):
    for r in range(0,data.shape[0]):
        if (data.iat[r,c] == "nan"):
            nan_coord.append([data.iat[r,0],data.columns[c],(r,c)])
            
# I'm not sure if having the alpha and/or numeric coordinates together
# or separate is better.  I want a good look at nan's per nutrient type

# %%
nan_coord[0:5]
# Out:
# [['Cornstarch', 'saturated_fat', (0, 4)],
#  ['Eggplant, raw', 'saturated_fat', (2, 4)],
#  ['PACE, Picante Sauce', 'saturated_fat', (10, 4)],
#  ['Goji berries, dried', 'saturated_fat', (11, 4)],
#  ['Mango nectar, canned', 'saturated_fat', (12, 4)]]

# %%
# I'll generate a df with two columns, food and nutrient_category 
coord_2d = [(x, y) for x, y, _ in nan_coord]

# Creating a dataframe from the 2D data
TwoDDF = pd.DataFrame(coord_2d, columns=['food', 'nutrient_category'])

# Displaying the dataframe
print(TwoDDF)
# Out:
#                                                    food nutrient_category
# 0                                            Cornstarch     saturated_fat
# 1                                         Eggplant, raw     saturated_fat
# 2                                   PACE, Picante Sauce     saturated_fat
# 3                                   Goji berries, dried     saturated_fat
# 4                                  Mango nectar, canned     saturated_fat
# ...                                                 ...               ...
# 1585  Beverages, prepared with water, frozen concent...     saturated_fat
# 1586  Apple juice, diluted with 3 volume water witho...     saturated_fat
# 1587  Carbonated beverage, without caffeine, with so...     saturated_fat
# 1588  Apple juice, with added ascorbic acid, diluted...     saturated_fat
# 1589  Pan Dulce, contains wheat flour and rice flour...     saturated_fat
#
# [1590 rows x 2 columns]

# %%
# saturated_fat is the only category with 'nan' values
TwoDDF[["nutrient_category"]].value_counts()
# Out:
# nutrient_category
# saturated_fat        1590
# dtype: int64

# %%
# convert nan for saturated_fat to 0

data.saturated_fat = [0 if val == 'nan' else val for val in data.saturated_fat]

# %%
data.dtypes
# Out:
# name              object
# serving_size      object
# calories          object
# total_fat         object
# saturated_fat    float64
#                   ...
# alcohol           object
# ash               object
# caffeine          object
# theobromine       object
# water             object
# Length: 76, dtype: object

# %%
for column in data.columns:
    try:
        data[column] = pd.to_numeric(data[column], errors='raise').astype(float)
    except ValueError:
        pass  # Ignore columns that cannot be converted to float

# %%
data.dtypes.value_counts() # all columns have been converted to float, 
# except "name"
# Out:
# float64    75
# object      1
# dtype: int64

# %%
data.head(2)
# Out:
#            name  serving_size  calories  total_fat  saturated_fat  \
# 0    Cornstarch         100.0     381.0        0.1            0.0
# 1  Nuts, pecans         100.0     691.0       72.0            6.2
#
#    cholesterol  sodium  choline  folate  folic_acid  ...    fat  \
# 0          0.0     9.0      0.4     0.0         0.0  ...   0.05
# 1          0.0     0.0     40.5    22.0         0.0  ...  71.97
#
#    saturated_fatty_acids  monounsaturated_fatty_acids  \
# 0                  0.009                        0.016
# 1                  6.180                       40.801
#
#    polyunsaturated_fatty_acids  fatty_acids_total_trans  alcohol   ash  \
# 0                        0.025                      0.0      0.0  0.09
# 1                       21.614                      0.0      0.0  1.49
#
#    caffeine  theobromine  water
# 0       0.0          0.0   8.32
# 1       0.0          0.0   3.52
#
# [2 rows x 76 columns]

# %%
[print(val) for val in data.columns.values];
# Out:
# name
# serving_size
# calories
# total_fat
# saturated_fat
# cholesterol
# sodium
# choline
# folate
# folic_acid
# niacin
# pantothenic_acid
# riboflavin
# thiamin
# vitamin_a
# vitamin_a_rae
# carotene_alpha
# carotene_beta
# cryptoxanthin_beta
# lutein_zeaxanthin
# lucopene
# vitamin_b12
# vitamin_b6
# vitamin_c
# vitamin_d
# vitamin_e
# tocopherol_alpha
# vitamin_k
# calcium
# copper
# irom
# magnesium
# manganese
# phosphorous
# potassium
# selenium
# zinc
# protein
# alanine
# arginine
# aspartic_acid
# cystine
# glutamic_acid
# glycine
# histidine
# hydroxyproline
# isoleucine
# leucine
# lysine
# methionine
# phenylalanine
# proline
# serine
# threonine
# tryptophan
# tyrosine
# valine
# carbohydrate
# fiber
# sugars
# fructose
# galactose
# glucose
# lactose
# maltose
# sucrose
# fat
# saturated_fatty_acids
# monounsaturated_fatty_acids
# polyunsaturated_fatty_acids
# fatty_acids_total_trans
# alcohol
# ash
# caffeine
# theobromine
# water

# %%
constraints_aa = pd.read_csv("./AminoAcids.csv")
constraints = pd.read_csv("./constraints.csv")
# remove notes from constraints
constraints = constraints.drop(['notes:'], axis = 1)

# store and remove units
constraints_units = {}
alpha = re.compile(r"[mcg]+",re.I) # generate pattern object
for r in range(0, constraints.shape[0]):
    s = constraints.Min[r] # get nutrient value
    try:
        m = alpha.search(constraints.Min[r]) # check pattern object against nutrient value, 
        constraints_units[constraints.nutrient[r]] = m.group()
        constraints.iat[r,1] = float(re.sub(r"[^0-9.]","",
                                     str(constraints.iat[r,1])))
        constraints.iat[r,2] = float(re.sub(r"[^0-9.]","",
                                     str(constraints.iat[r,2])))
    except:
        constraints_units[constraints.nutrient[r]] = "None"

constraints.Min = pd.to_numeric(constraints.Min)
constraints.Max = pd.to_numeric(constraints.Max)

# %%
constraints.dtypes
# Out:
# nutrient     object
# Min         float64
# Max         float64
# dtype: object

# %%
data.head().protein
# Out:
# 0     0.26
# 1     9.17
# 2     0.98
# 3    13.30
# 4     1.10
# Name: protein, dtype: float64

# %%
# I'll convert the units of vitamin_a  from IU to the current standard of mcg.
# The conversion is 1 IU = .3 mcg RAE
units["vitamin_a"]
data.vitamin_a = data.vitamin_a/.3

# %%
units["vitamin_a"] = 'mcg'

# %%
data.vitamin_a
# Out:
# 0         0.000000
# 1       186.666667
# 2        76.666667
# 3        30.000000
# 4       153.333333
#            ...
# 8784     36.666667
# 8785      0.000000
# 8786      0.000000
# 8787     13.333333
# 8788     20.000000
# Name: vitamin_a, Length: 8789, dtype: float64

# %%
constraints.head()
# Out:
#         nutrient     Min     Max
# 0       calories  2000.0  2000.0
# 1        protein    56.0   160.0
# 2      total_fat    22.2    78.0
# 3  saturated_fat     0.0    12.0
# 4    cholesterol     0.0     NaN

# %% [markdown]
# Which nutrients will I be using as constraints and what will I be optimizing.  Ultimately I would

# %%
data.head()
# Out:
#               name  serving_size  calories  total_fat  saturated_fat  \
# 0       Cornstarch         100.0     381.0        0.1            0.0
# 1     Nuts, pecans         100.0     691.0       72.0            6.2
# 2    Eggplant, raw         100.0      25.0        0.2            0.0
# 3   Teff, uncooked         100.0     367.0        2.4            0.4
# 4  Sherbet, orange         100.0     144.0        2.0            1.2
#
#    cholesterol  sodium  choline  folate  folic_acid  ...    fat  \
# 0          0.0     9.0      0.4     0.0         0.0  ...   0.05
# 1          0.0     0.0     40.5    22.0         0.0  ...  71.97
# 2          0.0     2.0      6.9    22.0         0.0  ...   0.18
# 3          0.0    12.0     13.1     0.0         0.0  ...   2.38
# 4          1.0    46.0      7.7     4.0         0.0  ...   2.00
#
#    saturated_fatty_acids  monounsaturated_fatty_acids  \
# 0                  0.009                        0.016
# 1                  6.180                       40.801
# 2                  0.034                        0.016
# 3                  0.449                        0.589
# 4                  1.160                        0.530
#
#    polyunsaturated_fatty_acids  fatty_acids_total_trans  alcohol   ash  \
# 0                        0.025                      0.0      0.0  0.09
# 1                       21.614                      0.0      0.0  1.49
# 2                        0.076                      0.0      0.0  0.66
# 3                        1.071                      0.0      0.0  2.37
# 4                        0.080                      1.0      0.0  0.40
#
#    caffeine  theobromine  water
# 0       0.0          0.0   8.32
# 1       0.0          0.0   3.52
# 2       0.0          0.0  92.30
# 3       0.0          0.0   8.82
# 4       0.0          0.0  66.10
#
# [5 rows x 76 columns]

# %%
constraints.head()
# Out:
#         nutrient     Min     Max
# 0       calories  2000.0  2000.0
# 1        protein    56.0   160.0
# 2      total_fat    22.2    78.0
# 3  saturated_fat     0.0    12.0
# 4    cholesterol     0.0     NaN

# %%
constraints_aa
# Out:
#                    AminoAcid         Min
# 0       cystine + methionine  19 mg/kg/d
# 1                  histidine  14 mg/kg/d
# 2                 isoleucine  19 mg/kg/d
# 3                    leucine  42 mg/kg/d
# 4                     lysine  38 mg/kg/d
# 5                 methionine  13 mg/kg/d
# 6   phenylalanine + tyrosine  33 mg/kg/d
# 7              phenylalanine  14 mg/kg/d
# 8                  threonine  20 mg/kg/d
# 9                 tryptophan   5 mg/kg/d
# 10                    valine  24 mg/kg/d

# %%
constraints_aa.head()
# Out:
#               AminoAcid         Min
# 0  cystine + methionine  19 mg/kg/d
# 1             histidine  14 mg/kg/d
# 2            isoleucine  19 mg/kg/d
# 3               leucine  42 mg/kg/d
# 4                lysine  38 mg/kg/d

# %%
constraints_aa = constraints_aa.dropna(how='any')
constraints_aa.reset_index(drop=True, inplace=True)

# %%
# remove units from the aminoacid constraints:
constraints_aa['Min'] = constraints_aa['Min'].str.extract('(\d+)', expand=False)

# %% [markdown]
# Bodyweight adjustment for AA requirements.

# %%
weight_kg = float(input("Enter your weight in kilograms: "))
# Out:
# Enter your weight in kilograms:  80

# %%
constraints_aa['Min'] = pd.to_numeric(constraints_aa['Min'])*weight_kg

# %% [markdown]
# [per EdChum](https://stackoverflow.com/questions/44117326/how-can-i-remove-all-non-numeric-characters-from-all-the-values-in-a-particular)

# %%
constraints = constraints.set_index('nutrient')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/7q/63cgxnn50sl5zwxkchv_j2cr0000gn/T/ipykernel_2509/1312420410.py in <module>
# ----> 1 constraints = constraints.set_index('nutrients')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5501
#    5502         if missing:
# -> 5503             raise KeyError(f"None of {missing} are in the columns")
#    5504
#    5505         if inplace:
#
# KeyError: "None of ['nutrients'] are in the columns"

# %%
constraints
# Out:
#                                 Min      Max
# nutrient
# calories                     2000.0   2000.0
# protein                        56.0    160.0
# total_fat                      22.2     78.0
# saturated_fat                   0.0     12.0
# cholesterol                     0.0      NaN
# sodium                       1500.0   2300.0
# choline                       550.0   3500.0
# folate                        400.0   1000.0
# folic_acid                      NaN      NaN
# niacin                         16.0     35.0
# pantothenic_acid                5.0      NaN
# riboflavin                      1.1      NaN
# thiamin                         1.2      NaN
# vitamin_a                     900.0   3000.0
# vitamin_a_rae                 900.0   3000.0
# carotene_alpha                  NaN      NaN
# carotene_beta                   NaN      NaN
# cryptoxanthin_beta              NaN      NaN
# lutein_zeaxanthin               NaN      NaN
# lucopene                        NaN      NaN
# vitamin_b12                     2.4      NaN
# vitamin_b6                      1.3    100.0
# vitamin_c                      90.0      NaN
# vitamin_d                       5.0     50.0
# vitamin_e                      15.0   1000.0
# tocopherol_alpha                NaN      NaN
# vitamin_k                     120.0      NaN
# calcium                      1000.0   2500.0
# copper                        900.0  10000.0
# irom                            8.0     40.0
# magnesium                     320.0      NaN
# manganese                       2.3     11.0
# phosphorous                   700.0   4000.0
# potassium                       4.7      NaN
# selenium                       55.0    400.0
# zink                           11.0     40.0
# carbohydrate                  225.0    400.0
# fiber                          28.0      NaN
# fat                            22.2     78.0
# saturated_fatty_acids           0.0     12.0
# monounsaturated_fatty_acids     NaN      NaN
# polyunsaturated_fatty_acids     NaN      NaN
# fatty_acids_total_trans         NaN      NaN
# alcohol                         NaN      NaN
# ash                             NaN      NaN
# caffeine                        NaN      NaN
# theobromine                     NaN      NaN
# water                           NaN      NaN
# molybdenum                     34.0   2000.0
# chloride                        2.3      3.6
# biotin                         30.0      NaN
# pantothenic_acid                NaN      NaN
# chromium                       35.0      NaN

# %%
data.columns
# Out:
# Index(['name', 'serving_size', 'calories', 'total_fat', 'saturated_fat',
#        'cholesterol', 'sodium', 'choline', 'folate', 'folic_acid', 'niacin',
#        'pantothenic_acid', 'riboflavin', 'thiamin', 'vitamin_a',
#        'vitamin_a_rae', 'carotene_alpha', 'carotene_beta',
#        'cryptoxanthin_beta', 'lutein_zeaxanthin', 'lucopene', 'vitamin_b12',
#        'vitamin_b6', 'vitamin_c', 'vitamin_d', 'vitamin_e', 'tocopherol_alpha',
#        'vitamin_k', 'calcium', 'copper', 'irom', 'magnesium', 'manganese',
#        'phosphorous', 'potassium', 'selenium', 'zinc', 'protein', 'alanine',
#        'arginine', 'aspartic_acid', 'cystine', 'glutamic_acid', 'glycine',
#        'histidine', 'hydroxyproline', 'isoleucine', 'leucine', 'lysine',
#        'methionine', 'phenylalanine', 'proline', 'serine', 'threonine',
#        'tryptophan', 'tyrosine', 'valine', 'carbohydrate', 'fiber', 'sugars',
#        'fructose', 'galactose', 'glucose', 'lactose', 'maltose', 'sucrose',
#        'fat', 'saturated_fatty_acids', 'monounsaturated_fatty_acids',
#        'polyunsaturated_fatty_acids', 'fatty_acids_total_trans', 'alcohol',
#        'ash', 'caffeine', 'theobromine', 'water'],
#       dtype='object')

# %%
data.name.values
# Out:
# array(['Cornstarch', 'Nuts, pecans', 'Eggplant, raw', ...,
#        'Lamb, raw, separable lean and fat, composite of trimmed retail cuts, frozen, imported, New Zealand',
#        'Beef, raw, all grades, trimmed to 0" fat, separable lean only, boneless, eye of round roast, round',
#        'Beef, raw, all grades, trimmed to 0" fat, separable lean only, boneless, eye of round steak, round'],
#       dtype=object)

# %%
# Out:
# food:Cornstarch type:<class 'str'>, i:0
# food:Nuts, pecans type:<class 'str'>, i:1
# food:Eggplant, raw type:<class 'str'>, i:2
# food:Teff, uncooked type:<class 'str'>, i:3
# food:Sherbet, orange type:<class 'str'>, i:4
# food:Cauliflower, raw type:<class 'str'>, i:5
# food:Taro leaves, raw type:<class 'str'>, i:6
# food:Lamb, raw, ground type:<class 'str'>, i:7
# food:Cheese, camembert type:<class 'str'>, i:8
# food:Vegetarian fillets type:<class 'str'>, i:9
# food:PACE, Picante Sauce type:<class 'str'>, i:10
# food:Beef sausage, cooked, fresh type:<class 'str'>, i:906
# food:Luncheon meat, canned, pork type:<class 'str'>, i:907
# food:MURRAY, Vanilla Sugar Wafer type:<class 'str'>, i:908
# food:Radishes, raw, white icicle type:<class 'str'>, i:909
# food:Vinespinach, raw, (basella) type:<class 'str'>, i:910
# food:Syrups, high-fructose, corn type:<class 'str'>, i:911
# food:Stew, steamed corn (Navajo) type:<class 'str'>, i:912
# food:OSCAR MAYER, Bologna (beef) type:<class 'str'>, i:913
# food:Ostrich, raw, outside strip type:<class 'str'>, i:914
# ...
# food:Beef, raw, choice, trimmed to 1/8" fat, separable lean and fat, boneless, top sirloin cap steak, loin type:<class 'str'>, i:8670
# food:Pork, raw,with added solution, separable lean and fat, blade (steaks), (Boston butt), shoulder, fresh type:<class 'str'>, i:8671
# food:Beef, cooked, all grades, trimmed to 0" fat, separable lean and fat, composite of trimmed retail cuts type:<class 'str'>, i:8672
# food:Beef, raw, choice, trimmed to 1/8" fat, separable lean and fat, lip-on, boneless, rib eye steak/roast type:<class 'str'>, i:8673
# food:Lamb, broiled, cooked, trimmed to 1/8" fat, separable lean and fat, loin, fresh, imported, Australian type:<class 'str'>, i:8674
# food:Beef, grilled, cooked, all grades, trimmed to 1/8" fat, separable lean only, boneless, top loin filet type:<class 'str'>, i:8675
# food:Beef, raw, all grades, trimmed to 0" fat, separable lean only, boneless, chuck eye Country-Style ribs type:<class 'str'>, i:8676
# food:Beef, raw, choice, trimmed to 0" fat, separable lean and fat, lip off, boneless, top loin steak, loin type:<class 'str'>, i:8677
# food:Beef, raw, select, trimmed to 0" fat, separable lean and fat, lip off, boneless, top loin steak, loin type:<class 'str'>, i:8678
# food:Beef, roasted, cooked, select, trimmed to 1/8" fat, separable lean and fat, large end (ribs 6-9), rib type:<class 'str'>, i:8679
# food:Beef, broiled, cooked, select, trimmed to 1/8" fat, separable lean and fat, large end (ribs 6-9), rib type:<class 'str'>, i:8680
# food:Beef, broiled, cooked, choice, trimmed to 1/8" fat, separable lean and fat, large end (ribs 6-9), rib type:<class 'str'>, i:8681
# food:Beef, roasted, cooked, choice, trimmed to 1/8" fat, separable lean and fat, large end (ribs 6-9), rib type:<class 'str'>, i:8682
# food:Beef, braised, cooked, choice, trimmed to 0" fat, separable lean and fat, boneless, short ribs, chuck type:<class 'str'>, i:8683
# food:Beef, braised, cooked, select, trimmed to 0" fat, separable lean and fat, boneless, short ribs, chuck type:<class 'str'>, i:8684
# food:Lamb, roasted, cooked, choice, trimmed to 1/8" fat, separable lean and fat, blade, shoulder, domestic type:<class 'str'>, i:8685
# food:Lamb, broiled, cooked, choice, trimmed to 1/8" fat, separable lean and fat, blade, shoulder, domestic type:<class 'str'>, i:8686
# food:Lamb, braised, cooked, choice, trimmed to 1/8" fat, separable lean and fat, blade, shoulder, domestic type:<class 'str'>, i:8687
# food:Lamb, roasted, cooked, choice, trimmed to 1/4" fat, separable lean only, sirloin half, leg, domestic type:<class 'str'>, i:8688
# food:Beef, roasted, cooked, all grades, trimmed to 0" fat, separable lean only, large end (ribs 6-9), rib type:<class 'str'>, i:8689
# food:Lamb, cooked, choice, trimmed to 1/4" fat, separable fat, composite of trimmed retail cuts, domestic type:<class 'str'>, i:8690
# food:Beef, raw, select, trimmed to 0" fat, separable lean and fat, boneless, chuck eye Country-Style ribs type:<class 'str'>, i:8691
# food:Beef, raw, choice, trimmed to 0" fat, separable lean and fat, boneless, chuck eye Country-Style ribs type:<class 'str'>, i:8692
# food:Beef, roasted, cooked, select, trimmed to 0" fat, separable lean only, tri-tip roast, bottom sirloin type:<class 'str'>, i:8693
# food:Carbonated beverage, without caffeine, with sodium saccharin, other than cola or pepper, low calorie type:<class 'str'>, i:8694
# food:Beef, broiled, cooked, select, trimmed to 0" fat, separable lean only, porterhouse steak, short loin type:<class 'str'>, i:8695
# food:Beef, cooked, all grades, trimmed to 1/8" fat, separable lean only, composite of trimmed retail cuts type:<class 'str'>, i:8696
# food:Lamb, raw, trimmed to 1/8" fat, separable lean and fat, shank half, leg, fresh, imported, Australian type:<class 'str'>, i:8697
# food:Beef, broiled, cooked, all grades, trimmed to 1/8" fat, separable lean only, steak, top round, round type:<class 'str'>, i:8698
# food:Pork, cooked, separable lean only, composite of trimmed retail cuts (leg, loin, and shoulder), fresh type:<class 'str'>, i:8699
# food:Beef, raw, choice, trimmed to 1/8" fat, separable lean and fat, lip-on, bone-in, rib eye steak/roast type:<class 'str'>, i:8700
# food:Beef, raw, select, trimmed to 1/8" fat, separable lean and fat, lip-on, bone-in, rib eye steak/roast type:<class 'str'>, i:8701
# food:Beef, broiled, cooked, all grades, trimmed to 0" fat, separable lean only, inside skirt steak, plate type:<class 'str'>, i:8702
# food:Infant formula, not reconstituted, liquid concentrate, with iron, ADVANCE, SIMILAC, ABBOTT NUTRITION type:<class 'str'>, i:8703
# food:Lamb, raw, trimmed to 1/8" fat, separable lean and fat, blade, shoulder, fresh, imported, Australian type:<class 'str'>, i:8704
# food:Beef, grilled, cooked, select, trimmed to 1/8" fat, separable lean and fat, t-bone steak, short loin type:<class 'str'>, i:8705
# food:Beef, raw, all grades, trimmed to 0" fat, separable lean only, boneless, shoulder pot roast or steak type:<class 'str'>, i:8706
# food:Beef, raw, choice, trimmed to 0" fat, separable lean and fat, steak, top blade, shoulder clod, chuck type:<class 'str'>, i:8707
# food:Beef, raw, select, trimmed to 0" fat, separable lean and fat, steak, top blade, shoulder clod, chuck type:<class 'str'>, i:8708
# food:Beef, roasted, cooked, choice, trimmed to 0" fat, separable lean only, tri-tip roast, bottom sirloin type:<class 'str'>, i:8709
# food:Beef, roasted, cooked, choice, trimmed to 0" fat, separable lean only, boneless, ribeye petite roast type:<class 'str'>, i:8710
# food:Beef, roasted, cooked, select, trimmed to 0" fat, separable lean only, boneless, ribeye petite roast type:<class 'str'>, i:8711
# food:Infant formula, with ARA and DHA, ready-to-feed, with iron, LIPIL, NUTRAMIGEN, ENFAMIL, MEAD JOHNSON type:<class 'str'>, i:8712
# food:Beef, raw, all grades, trimmed to 1/8" fat, separable lean and fat, composite of trimmed retail cuts type:<class 'str'>, i:8713
# food:Pork, raw, separable lean and fat, composite of trimmed retail cuts (loin and shoulder blade), fresh type:<class 'str'>, i:8714
# food:Pork, cooked, separable lean only, composite of trimmed retail cuts (loin and shoulder blade), fresh type:<class 'str'>, i:8715
# food:Beef, roasted, cooked, select, trimmed to 1/8" fat, separable lean only, roast, bottom round , round type:<class 'str'>, i:8716
# food:Beef, braised, cooked, select, trimmed to 0" fat, separable lean and fat, steak, bottom round, round type:<class 'str'>, i:8717
# food:Beef, roasted, cooked, select, trimmed to 0" fat, separable lean and fat, roast, bottom round, round type:<class 'str'>, i:8718
# food:Beef, roasted, cooked, choice, trimmed to 0" fat, separable lean and fat, roast, bottom round, round type:<class 'str'>, i:8719
# food:Beef, braised, cooked, choice, trimmed to 0" fat, separable lean and fat, steak, bottom round, round type:<class 'str'>, i:8720
# food:Beef, raw, all grades, trimmed to 0" fat, separable lean and fat, boneless, mock tender steak, chuck type:<class 'str'>, i:8721
# food:Beef, broiled, cooked, choice, trimmed to 0" fat, separable lean only, porterhouse steak, short loin type:<class 'str'>, i:8722
# food:Beef, grilled, cooked, select, trimmed to 1/8" fat, separable lean and fat, boneless, top loin filet type:<class 'str'>, i:8723
# food:Beef, grilled, cooked, choice, trimmed to 1/8" fat, separable lean and fat, boneless, top loin filet type:<class 'str'>, i:8724
# food:Beef, grilled, cooked, select, trimmed to 1/8" fat, separable lean only, steak, top loin, short loin type:<class 'str'>, i:8725
# food:Beef, broiled, cooked, select, trimmed to 1/8" fat, separable lean only, small end (ribs 10-12), rib type:<class 'str'>, i:8726
# food:Beef, broiled, cooked, choice, trimmed to 1/8" fat, separable lean only, steak, top loin, short loin type:<class 'str'>, i:8727
# food:Infant formula, prepared from liquid concentrate, DHA and ARA, with iron, GOOD START SUPREME, NESTLE type:<class 'str'>, i:8728
# food:Beef, grilled, cooked, choice, trimmed to 1/8" fat, separable lean and fat, t-bone steak, short loin type:<class 'str'>, i:8729
# food:Beef, raw, all grades, trimmed to 0" fat, separable lean and fat, boneless, shoulder top blade steak type:<class 'str'>, i:8730
# food:Fast foods, regular patty; double decker bun with condiments and special sauce, cheeseburger; double type:<class 'str'>, i:8731
# food:Beef, grilled, cooked, all grades, trimmed to 0" fat, separable lean only, boneless, chuck eye steak type:<class 'str'>, i:8732
# food:Beef, broiled, cooked, prime, trimmed to 1/8" fat, separable lean and fat, large end (ribs 6-9), rib type:<class 'str'>, i:8733
# food:Beef, roasted, cooked, prime, trimmed to 1/8" fat, separable lean and fat, large end (ribs 6-9), rib type:<class 'str'>, i:8734
# food:Beef, roasted, cooked, select, trimmed to 0" fat, separable lean and fat, large end (ribs 6-9), rib type:<class 'str'>, i:8735
# food:Beef, roasted, cooked, choice, trimmed to 0" fat, separable lean and fat, large end (ribs 6-9), rib type:<class 'str'>, i:8736
# food:Beef, cooked, select, trimmed to 1/8" fat, separable lean and fat, composite of trimmed retail cuts type:<class 'str'>, i:8737
# food:Beef, braised, cooked, all grades, trimmed to 1/8" fat, separable lean and fat, point half, brisket type:<class 'str'>, i:8738
# food:Beef, raw, select, trimmed to 0" fat, separable lean and fat, boneless, shoulder pot roast or steak type:<class 'str'>, i:8739
# food:Beef, broiled, cooked, choice, trimmed to 1/8" fat, separable lean and fat, steak, top round, round type:<class 'str'>, i:8765
# food:Beef, roasted, cooked, choice, trimmed to 1/8" fat, separable lean only, roast, bottom round, round type:<class 'str'>, i:8766
# food:Toddler formula, ready-to-feed, ENFAGROW PREMIUM (formerly ENFAMIL, LIPIL, NEXT STEP), MEAD JOHNSON type:<class 'str'>, i:8767
# food:Beef, broiled, cooked, select, trimmed to 1/8" fat, separable lean and fat, steak, top round, round type:<class 'str'>, i:8768
# food:Beef, grilled, cooked, all grades, trimmed to 0" fat, separable lean only, boneless, shoulder steak type:<class 'str'>, i:8769
# food:Infant formula, with ARA and DHA, SENSITIVE (LACTOSE FREE) ready-to-feed, SIMILAC, ABBOTT NUTRITION type:<class 'str'>, i:8770
# food:Infant formula, not reconstituted, liquid concentrate, with iron, GOOD START ESSENTIALS SOY, NESTLE type:<class 'str'>, i:8771
# food:Pan Dulce, contains wheat flour and rice flour, cookie-like, Salpora de Arroz con Azucar, LA RICURA type:<class 'str'>, i:8772
# food:Beef, raw, select, trimmed to 1/8" fat, separable lean only, lip-on, boneless, top loin steak, loin type:<class 'str'>, i:8773
# food:Beef, raw, choice, trimmed to 1/8" fat, separable lean only, lip-on, boneless, top loin steak, loin type:<class 'str'>, i:8774
# food:Beef, raw, all grades, trimmed to 0" fat, separable lean only, boneless, ribeye  petite roast/filet type:<class 'str'>, i:8775
# food:Beef, broiled, cooked, all grades, trimmed to 0" fat, separable lean only, mock tender steak, chuck type:<class 'str'>, i:8776
# food:Beef, broiled, cooked, choice, trimmed to 1/8" fat, separable lean and fat, whole (ribs 6-12), rib type:<class 'str'>, i:8777
# food:Beef, roasted, cooked, choice, trimmed to 1/8" fat, separable lean and fat, whole (ribs 6-12), rib type:<class 'str'>, i:8778
# food:Beef, braised, cooked, all grades, trimmed to 1/8" fat, separable lean and fat, flat half, brisket type:<class 'str'>, i:8779
# food:Beef, raw, select, trimmed to 1/8" fat, separable lean only, lip-on, boneless, rib eye steak/roast type:<class 'str'>, i:8780
# food:Beef, raw, choice, trimmed to 1/8" fat, separable lean only, lip-on, boneless, rib eye steak/roast type:<class 'str'>, i:8781
# food:Oil, uses similar to 95 degree hard butter, confection fat, palm kernel (hydrogenated), industrial type:<class 'str'>, i:8782
# food:Beef, raw, all grades, trimmed to 0" fat, separable lean and fat, boneless, top round steak, round type:<class 'str'>, i:8783
# food:Beef, raw, all grades, trimmed to 0" fat, separable lean and fat, boneless, top round roast, round type:<class 'str'>, i:8784
# food:Lamb, cooked, separable lean only, composite of trimmed retail cuts, frozen, imported, New Zealand type:<class 'str'>, i:8785
# food:Lamb, raw, separable lean and fat, composite of trimmed retail cuts, frozen, imported, New Zealand type:<class 'str'>, i:8786
# food:Beef, raw, all grades, trimmed to 0" fat, separable lean only, boneless, eye of round roast, round type:<class 'str'>, i:8787
# food:Beef, raw, all grades, trimmed to 0" fat, separable lean only, boneless, eye of round steak, round type:<class 'str'>, i:8788

# %%
def check_for_food(string, food):
    pattern = re.compile(r"\b" + re.escape(food) + r"\b",re.I)
    match = re.search(pattern, string)
    if match:
        return True
    else:
        return False

# %%
apples_match = []
sardines_match = []

for i, food in enumerate(data.name.values):
    if check_for_food(food,'Apples'):
        apples_match.append(True)
    else:
        apples_match.append(False)
    if check_for_food(food, 'Sardines')
# Out:
#   File "/var/folders/7q/63cgxnn50sl5zwxkchv_j2cr0000gn/T/ipykernel_2509/2727234722.py", line 9
#     if check_for_sardines()
#                            ^
# SyntaxError: invalid syntax
